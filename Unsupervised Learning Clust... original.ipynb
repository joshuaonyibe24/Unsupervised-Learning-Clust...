# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('CC GENERAL.csv')

# %%
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
data.shape
# Out:
# (8950, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
data.corr()
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.322412   0.181261
# BALANCE_FREQUENCY                 0.322412           1.000000   0.133674
# PURCHASES                         0.181261           0.133674   1.000000
# ONEOFF_PURCHASES                  0.164350           0.104323   0.916845
# INSTALLMENTS_PURCHASES            0.126469           0.124292   0.679896
# CASH_ADVANCE                      0.496692           0.099388  -0.051474
# PURCHASES_FREQUENCY              -0.077944           0.229715   0.393017
# ONEOFF_PURCHASES_FREQUENCY        0.073166           0.202415   0.498430
# PURCHASES_INSTALLMENTS_FREQUENCY -0.063186           0.176079   0.315567
# CASH_ADVANCE_FREQUENCY            0.449218           0.191873  -0.120143
# CASH_ADVANCE_TRX                  0.385152           0.141555  -0.067175
# PURCHASES_TRX                     0.154338           0.189626   0.689561
# ...

# %%
data['MINIMUM_PAYMENTS'].fillna(data['MINIMUM_PAYMENTS'].median(),inplace=True)

# %%
data['CREDIT_LIMIT'].fillna(data['CREDIT_LIMIT'].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
data = data.drop('CUST_ID', axis = 1)

# %%
data_a = list(data.select_dtypes(include=['float64', 'int64']).columns)

# %%
plt.figure(figsize = (20,40))
x = 1
for column in data_a:
    plt.subplot(9, 3, x)
    
    
    
    
    
    
    
    
    
    
    
    
    
    sb.distplot(data[column])
    plt.title('Distribution {}'.format(column), fontsize=10, color ='dimgrey', fontweight = 'bold', y=0.90)
    x += 1
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# hierarchical clustering

# %%
x = data

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_scaled = sc.fit_transform(x)
x_scaled
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.3024    ,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.09749953,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.0932934 ,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.32687479,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.33830497,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.3243581 ,
#         -0.52555097, -4.12276757]])

# %%
# fit the model

from sklearn.cluster import AgglomerativeClustering 

model = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='complete')

# %%
agglomerative=pd.DataFrame(clust_labels)
agglomerative
# Out:
#       0
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2
# ...  ..
# 8945  2
# 8946  2
# 8947  2
# 8948  2
# 8949  2
#
# [8950 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(20,7))
plt.title("Customer Dendrograms")
dend=shc.dendrogram(shc.linkage(data, method="complete"))

# %% [markdown]
# Partitioning clustering

# %%
X = data[[ 'PAYMENTS','CASH_ADVANCE']]

# %%
clust_labels = model.fit_predict(X)

clust_df = pd.DataFrame(clust_labels)

clust_df.value_counts()
# Out:
# 0    5894
# 6    1154
# 3    1133
# 8     342
# 2     266
# 1      84
# 5      43
# 7      18
# 4      16
# dtype: int64

# %%
import matplotlib.pyplot as plt
fig =plt.figure(figsize=(16,5))
ax = fig.add_subplot(1,1,1)
scatter = ax.scatter(data['PAYMENTS'] , data["CASH_ADVANCE"], s=50, c=clust_df[0])


ax.set_title("Agglomerative Clutering")
ax.set_xlabel("PAYMENTS:")
ax.set_ylabel("CASH_ADVANCE")
plt.colorbar(scatter)

# %%
from sklearn.cluster import KMeans  #Importing our clustering algorithm: KMeans

model2 = KMeans(n_clusters=5, random_state=0)  #Cluster our data by choosing 5 as number of clusters

X_train = X.loc[:180]
X_test = X.loc[180:]

model2.fit(X_train)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
labels = pd.DataFrame(model2.labels_)

labels.tail()

labels.shape
# Out:
# (181, 1)

# %%
labels[0].value_counts().sort_values(ascending=False)
# Out:
# 0    123
# 4     41
# 3      8
# 1      8
# 2      1
# Name: 0, dtype: int64

# %%
y_pred = model2.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 3, ..., 0, 0, 0])

# %%
model2.cluster_centers_
# Out:
# array([[  786.55883345,   316.84718052],
#        [13676.36996637,  1279.85177075],
#        [28232.69446   , 27296.48576   ],
#        [ 6506.28381775,  8345.441898  ],
#        [ 3073.66395732,  1936.39029441]])

# %%
from sklearn.metrics import silhouette_score
print(f'Silhouette Score(n=2): {silhouette_score(X_test, y_pred)}')
# Out:
# Silhouette Score(n=2): 0.5654602025411469

# %%
print(f'Silhouette Score(n=2): {silhouette_score(X_train, model2.predict(X_train))}')
# Out:
# Silhouette Score(n=2): 0.5195623549583669

# %%
sum_of_squared_dist = []

for i in range(1,10):
  model = KMeans(n_clusters=i)
  model.fit(X_train)
  sum_of_squared_dist.append(model.inertia_)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.figure(figsize=(16,8))

plt.plot(range(1,10), sum_of_squared_dist, color='r')
plt.xlabel('Number of clusters')
plt.ylabel('Sum of squared error')
plt.title('Sum of squared error vs Number of clusters')
plt.show()

# %% [markdown]
# we have chosen K=2 as the best K-value.

# %%
#Interpretation
#With nine groups, agglomerative clustering generated the highest silhouette score of 56% (0.565).

#Similarly, cluster 3 was where the eblow graph for kmeans first appeared.

#Kmeans clustering outperformed agglomerative clustering in performance.
